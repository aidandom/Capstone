# %%
import pandas as pd

rankings = pd.read_csv("./datasets/rankings_1973-2017_csv.csv")
# Out:
# /Users/aidandominguez/opt/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
rankings.head()
# Out:
#    week_title  week_year  week_month  week_day rank_text  rank_number  \
# 0  2017.11.20       2017          11        20         1            1
# 1  2017.11.20       2017          11        20         2            2
# 2  2017.11.20       2017          11        20         3            3
# 3  2017.11.20       2017          11        20         4            4
# 4  2017.11.20       2017          11        20         5            5
#
#    move_positions move_direction  player_age  ranking_points  tourneys_played  \
# 0             NaN            NaN        31.0           10645               18
# 1             NaN            NaN        36.0            9605               17
# 2             3.0             up        26.0            5150               23
# 3             1.0           down        20.0            4610               25
# 4             1.0           down        24.0            4015               27
#
#                                    player_url       player_slug player_id
# ...

# %%
drop_labels = ["week_title", 
               "rank_text",
               "player_url"]
rankings.drop(columns=drop_labels, inplace = True)

# %%
rankings = rankings.loc[rankings["week_year"] == 2017]

# %%
rankings = rankings.loc[(rankings["week_month"] == 11) | (rankings["week_month"] == 1)]

# %%
rankings.loc[rankings["week_month"] == 1, "week_day"].unique()
# Out:
# array([30, 16,  9,  2])

# %%
rankings.loc[rankings["week_month"] == 11, "week_day"].unique()
# Out:
# array([20, 13,  6])

# %%
month_day_filter = (rankings["week_month"] == 11 & rankings["week_day"] == 20)

# %%
rankings.head()
# Out:
#    week_year  week_month  rank_number  move_positions move_direction  \
# 0       2017          11            1             NaN            NaN
# 1       2017          11            2             NaN            NaN
# 2       2017          11            3             3.0             up
# 3       2017          11            4             1.0           down
# 4       2017          11            5             1.0           down
#
#    player_age  ranking_points  tourneys_played       player_slug player_id
# 0        31.0           10645               18      rafael-nadal      n409
# 1        36.0            9605               17     roger-federer      f324
# 2        26.0            5150               23   grigor-dimitrov      d875
# 3        20.0            4610               25  alexander-zverev      z355
# 4        24.0            4015               27     dominic-thiem      tb69

# %%
rankings_ind = rankings.set_index(rankings["player_slug"])
rankings_ind.drop(columns=["move_direction", "week_year"], inplace=True)
rankings_ind.head()
# Out:
#                   week_month  rank_number  move_positions  player_age  \
# player_slug
# rafael-nadal              11            1             NaN        31.0
# roger-federer             11            2             NaN        36.0
# grigor-dimitrov           11            3             3.0        26.0
# alexander-zverev          11            4             1.0        20.0
# dominic-thiem             11            5             1.0        24.0
#
#                   ranking_points  tourneys_played       player_slug player_id
# player_slug
# rafael-nadal               10645               18      rafael-nadal      n409
# roger-federer               9605               17     roger-federer      f324
# grigor-dimitrov             5150               23   grigor-dimitrov      d875
# alexander-zverev            4610               25  alexander-zverev      z355
# dominic-thiem               4015               27     dominic-thiem      tb69

# %%
rankings_ind[rankings_ind["rank_number"] == 1]
# Out:
#               week_month  rank_number  move_positions  player_age  \
# player_slug
# rafael-nadal          11            1             NaN        31.0
# rafael-nadal          11            1             NaN        31.0
# rafael-nadal          11            1             NaN        31.0
# andy-murray            1            1             NaN        29.0
# andy-murray            1            1             NaN        29.0
# andy-murray            1            1             NaN        29.0
# andy-murray            1            1             NaN        29.0
#
#               ranking_points  tourneys_played   player_slug player_id
# player_slug
# rafael-nadal           10645               18  rafael-nadal      n409
# rafael-nadal           10645               17  rafael-nadal      n409
# rafael-nadal           10645               17  rafael-nadal      n409
# andy-murray            11540               17   andy-murray      mc10
# ...
